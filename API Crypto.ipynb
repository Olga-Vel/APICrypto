# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'c282f6df-5c07-461f-83b6-4744768c9132',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-07-13T19:17:10.897Z', 'error_code': 0, 'error_message': None, 'elapsed': 17, 'credit_count': 1, 'notice': None, 'total_count': 10193}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10341, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
# Out:
# C:\Users\velic\AppData\Local\Temp\ipykernel_19964\434265081.py:2: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')

# %%
def api_runner():
   
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'c282f6df-5c07-461f-83b6-4744768c9132',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now')
    df = df.append(df2)
    #df_append = pd.DataFrame(df2)
    #df = pd.concat([df,df_append])
    df
    
    if not os.path.isfile(r'C:\Users\velic\Desktop\PROGRAMMING\JupiterPythonScipts\API.csv'):
        df.to_csv(r'C:\Users\velic\Desktop\PROGRAMMING\JupiterPythonScipts\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\velic\Desktop\PROGRAMMING\JupiterPythonScipts\API.csv', mode='a',header=False)

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# {'status': {'timestamp': '2023-07-13T15:26:58.420Z', 'error_code': 0, 'error_message': None, 'elapsed': 32, 'credit_count': 1, 'notice': None, 'total_count': 10226}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10341, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
df72 = pd.read_csv(r'C:\Users\velic\Desktop\PROGRAMMING\JupiterPythonScipts\API.csv') 
df72
# Out:
#      Unnamed: 0    id             name symbol             slug  \
# 0             0     1          Bitcoin    BTC          bitcoin
# 1             1  1027         Ethereum    ETH         ethereum
# 2             2   825           Tether   USDT           tether
# 3             3  1839              BNB    BNB              bnb
# 4             4  3408         USD Coin   USDC         usd-coin
# 5             5    52              XRP    XRP              xrp
# 6             6  2010          Cardano    ADA          cardano
# 7             7    74         Dogecoin   DOGE         dogecoin
# 8             8  5426           Solana    SOL           solana
# 9             9     2         Litecoin    LTC         litecoin
# 10           10  3890          Polygon  MATIC          polygon
# 11           11  1958             TRON    TRX             tron
# 12           12  6636         Polkadot    DOT     polkadot-new
# 13           13  1831     Bitcoin Cash    BCH     bitcoin-cash
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id             name symbol             slug  num_market_pairs  \
# 0      1          Bitcoin    BTC          bitcoin             10341
# 1   1027         Ethereum    ETH         ethereum              7112
# 2    825           Tether   USDT           tether             56798
# 3     52              XRP    XRP              xrp               984
# 4   1839              BNB    BNB              bnb              1498
# 5   3408         USD Coin   USDC         usd-coin             13298
# 6   2010          Cardano    ADA          cardano               867
# 7   5426           Solana    SOL           solana               485
# 8     74         Dogecoin   DOGE         dogecoin               742
# 9   3890          Polygon  MATIC          polygon               771
# 10     2         Litecoin    LTC         litecoin               945
# 11  1958             TRON    TRX             tron               786
# 12  6636         Polkadot    DOT     polkadot-new               530
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
df3
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                             -0.02069                       3.10382
# Ethereum                            -1.05726                       5.64246
# Tether                               0.01665                       0.05976
# XRP                                  0.70602                      69.43980
# BNB                                 -1.42766                       3.94142
# USD Coin                             0.02118                       0.02212
# Cardano                              1.85725                      18.33824
# Solana                              -3.19991                      15.57284
# Dogecoin                            -0.91892                       7.07771
# Polygon                             -2.52028                      16.86945
# Litecoin                            -1.60140                       6.86096
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin          quote.USD.percent_change_1h     -0.02069
#                  quote.USD.percent_change_24h     3.10382
#                  quote.USD.percent_change_7d      3.74370
#                  quote.USD.percent_change_30d    21.35226
#                  quote.USD.percent_change_60d    16.66748
#                  quote.USD.percent_change_90d     3.90312
# Ethereum         quote.USD.percent_change_1h     -1.05726
#                  quote.USD.percent_change_24h     5.64246
#                  quote.USD.percent_change_7d      5.42158
#                  quote.USD.percent_change_30d    14.28481
#                  quote.USD.percent_change_60d    10.65508
#                  quote.USD.percent_change_90d    -4.08531
# Tether           quote.USD.percent_change_1h      0.01665
#                  quote.USD.percent_change_24h     0.05976
#                  quote.USD.percent_change_7d      0.05920
#                  quote.USD.percent_change_30d     0.08633
# ...

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                                 values
# name
# Bitcoin         quote.USD.percent_change_1h   -0.10482
#                 quote.USD.percent_change_24h   1.47448
#                 quote.USD.percent_change_7d    2.01061
#                 quote.USD.percent_change_30d  19.55854
#                 quote.USD.percent_change_60d  14.61003
#                 quote.USD.percent_change_90d   2.03228
# Ethereum        quote.USD.percent_change_1h    0.60849
#                 quote.USD.percent_change_24h   4.20401
#                 quote.USD.percent_change_7d    4.13926
#                 quote.USD.percent_change_30d  13.14246
#                 quote.USD.percent_change_60d   8.69579
#                 quote.USD.percent_change_90d  -5.37457
# Tether          quote.USD.percent_change_1h    0.00944
#                 quote.USD.percent_change_24h   0.04201
#                 quote.USD.percent_change_7d    0.05139
#                 quote.USD.percent_change_30d   0.07161
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index= pd.Index(range(90))
df6 = df5.reset_index()
df6
# Out:
#                name                       level_1    values
# 0           Bitcoin   quote.USD.percent_change_1h  -0.10482
# 1           Bitcoin  quote.USD.percent_change_24h   1.47448
# 2           Bitcoin   quote.USD.percent_change_7d   2.01061
# 3           Bitcoin  quote.USD.percent_change_30d  19.55854
# 4           Bitcoin  quote.USD.percent_change_60d  14.61003
# 5           Bitcoin  quote.USD.percent_change_90d   2.03228
# 6          Ethereum   quote.USD.percent_change_1h   0.60849
# 7          Ethereum  quote.USD.percent_change_24h   4.20401
# 8          Ethereum   quote.USD.percent_change_7d   4.13926
# 9          Ethereum  quote.USD.percent_change_30d  13.14246
# 10         Ethereum  quote.USD.percent_change_60d   8.69579
# 11         Ethereum  quote.USD.percent_change_90d  -5.37457
# 12           Tether   quote.USD.percent_change_1h   0.00944
# 13           Tether  quote.USD.percent_change_24h   0.04201
# 14           Tether   quote.USD.percent_change_7d   0.05139
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#                name                percent_change    values
# 0           Bitcoin   quote.USD.percent_change_1h  -0.10482
# 1           Bitcoin  quote.USD.percent_change_24h   1.47448
# 2           Bitcoin   quote.USD.percent_change_7d   2.01061
# 3           Bitcoin  quote.USD.percent_change_30d  19.55854
# 4           Bitcoin  quote.USD.percent_change_60d  14.61003
# 5           Bitcoin  quote.USD.percent_change_90d   2.03228
# 6          Ethereum   quote.USD.percent_change_1h   0.60849
# 7          Ethereum  quote.USD.percent_change_24h   4.20401
# 8          Ethereum   quote.USD.percent_change_7d   4.13926
# 9          Ethereum  quote.USD.percent_change_30d  13.14246
# 10         Ethereum  quote.USD.percent_change_60d   8.69579
# 11         Ethereum  quote.USD.percent_change_90d  -5.37457
# 12           Tether   quote.USD.percent_change_1h   0.00944
# 13           Tether  quote.USD.percent_change_24h   0.04201
# 14           Tether   quote.USD.percent_change_7d   0.05139
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h', '24h','7d','30d','60d','90d'])
df7
# Out:
#                name percent_change    values
# 0           Bitcoin             1h  -0.10482
# 1           Bitcoin            24h   1.47448
# 2           Bitcoin             7d   2.01061
# 3           Bitcoin            30d  19.55854
# 4           Bitcoin            60d  14.61003
# 5           Bitcoin            90d   2.03228
# 6          Ethereum             1h   0.60849
# 7          Ethereum            24h   4.20401
# 8          Ethereum             7d   4.13926
# 9          Ethereum            30d  13.14246
# 10         Ethereum            60d   8.69579
# 11         Ethereum            90d  -5.37457
# 12           Tether             1h   0.00944
# 13           Tether            24h   0.04201
# 14           Tether             7d   0.05139
# 15           Tether            30d   0.07161
# 16           Tether            60d   0.01290
# 17           Tether            90d  -0.03229
# 18              BNB             1h   0.30110
# 19              BNB            24h   3.76985
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values',hue='name', data=df7, kind='point')
